# %%
import seaborn as sns #SNS= Samuel Norman Seaborn
import matplotlib.pyplot as plt

# %%
sns.scatterplot(x='var x', y= 'var y')
plt.show()

sns.countplot(x='var x', data= df)
plt.show()

# %% [markdown]
# **Añadir tercer variable con hue**

# %%
sns.scatterplot(x='var x',
               y= 'var y',
               data= df,
               hue='tercer variable')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)
#
# **También, añade la leyenda en forma automática!!**
#
# Tambien, puede ordenarse la disposición de la tercer variable, pasandole una lista al argumento 'hue_order'

# %%
sns.scatterplot(x='var x',
               y= 'var y',
               data= df,
               hue='tercer variable',
               hue_order=[*list*])
plt.show()

# %% [markdown]
# Tambien puedo cambiar el color asignado a cada categoría con el argumento 'palette':

# %%
#Aplicado a un ejemplo:
hue_colors= {'Yes': 'black', 
            'No': 'red'}
sns.scatterplot(x='total_bill',
               y= 'tip',
               data= tips,
               hue='smoker',
               palette= hue_colors)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# hue funciona para cualquier tipo de gráfico!

# %% [markdown]
# **Plots relacionales y subplots**
#
#     Relaciones entre dos variables cuantitativas
# Para esto vamos a usar la función **relplot()** (relational plot), que nos permite hacer el estudio de estos plots relacionales. Nos permite crear subplots en una sola figura.
# Para hacer un scatterplot con relplot hacemos:

# %%
sns.relplot(x='var x', 
           y= 'var y', 
           data= df, 
           kind= 'scatter')
plt.show()

# %% [markdown]
# Si seteamos el argumento **'col'** o **'row'**, podemos hacer lo que hace 'hue', pero en distintos gráficos. Veamos como cambia esto cuando lo graficamos:

# %%
sns.relplot(x='var x', 
           y= 'var y', 
           data= df, 
           kind= 'scatter', 
           col='tercer variable')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **También podemos utilizar row y col al mismo tiempo para filtrar por dos variables distintas**

# %%
sns.relplot(x='var x', 
           y= 'var y', 
           data= df, 
           kind= 'scatter', 
           col='tercer variable',
           row='cuarta variable')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Si tenes muchos gráficos por fila, podes utilizar el parámetro **'col_wrap'** para especificar cuántos subplots queres por fila. O cambiar también el orden de los elementos que se van a disponer con el parámetro **'col_order'** al cual le vamso a pasar una lista con los valores ordenados.

# %%
sns.relplot(x='var x', 
           y= 'var y', 
           data= df, 
           kind= 'scatter', 
           col='tercer variable',
           col_wrap=2,
           col_order=[])
plt.show()

# %% [markdown]
# **Otras customizaciones**

# %% [markdown]
# **Para cambiar el tamaño de los puntos del scatterplot en base a una variable**, le tengo que agregar el parámetro **'size'** al codigo con el nombre de la variable a considerar.
# Para que se entienda mejor, **es aconsejable combinarlo con el parámetro 'hue' así cambia de color también**.

# %%
sns.relplot(x='var x', 
           y= 'var y', 
           data= df, 
           kind= 'scatter', 
           size='tercer var',
           hue='tercer var')
plt.show()

# %% [markdown]
# Otra variante que tenemos para añadirle es el parámetro **'style'**, que cambia el tipo de estilos de punto para cada valor de una variable.

# %%
sns.relplot(x='var x', 
           y= 'var y', 
           data= df, 
           kind= 'scatter', 
           hue='tercer var', 
           style='tercer var')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Otra customización es sobre la **transparencia de los puntos**. Esto se hace con el parámetro **'alpha'**, al cual se le pasa un valor entre 0 y 1, donde 1 es sin transparencia.

# %%
sns.relplot(x='var x', 
           y= 'var y', 
           data= df, 
           kind= 'scatter', 
           alpha= 0.4)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Line plots**

# %%
sns.relplot(x= 'var x',
            y= 'var y',
            data= df,
            kind= 'line')
plt.show()

# %% [markdown]
# A esto se le pueden añadir múltiples modificaciones, que vamos a ver a través del siguiente caso:

# %%
sns.relplot(x= 'var x',
            y= 'var y',
            data= df,
            kind= 'line', 
            style= 'tercer var',
            hue= 'tercer var', 
            markers= True)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Acá podemos ver que añadiendo **style**, voy a tener lineplots con distinto estilo de lineas. Al añadir **hue** hacemos que estas lineas cambien de color. Finalmente, agregando **markers = True** se va a generar un marcador para cada punto en la data.
# Si no queres que los estilos de las lineas cambien por subgrupo, pero si los marcadores de los puntos, tenes que añadirle a esto **dashes= False**

# %% [markdown]
# Si un lineplot tiene muchas observaciones por valor de x, los va a agregar. Por defecto utiliza la media. Al mismo tiempo, seaborn por defecto calcula un intervalo de confianza para esa media (del 95%)
#
# ![image.png](attachment:image.png)
#
# Pero, tambien puede ser que en lugar de querer ver el intervalo de confianza, nos interese saber qué tan variados son los valores de la variable que estamos analizando. Para esto podemos visualizar el desvío estandar. Para lo cual vamos a especificarlo con el argumento **ci**.

# %%
sns.relplot(x= 'var x',
            y= 'var y',
            data= df,
            kind= 'line', 
            ci= 'sd')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Tambien podemos sacar el intervalo de confianza poniendo ci= None**

# %% [markdown]
# **Plots categóricos**

# %% [markdown]
# Como tenemos **relplot()** para plots relacionales, tenemos **catplot()** para plots categóricos.

# %%
sns.catplot(x= 'variable categorica',
            data= df, 
            kind='count')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Para ordenar los valores, creamos una lista estableciendo el orden que queremos darle a las filas y después se la pasamos al argumento **order**

# %%
lista_de_orden= []

sns.catplot(x= 'variable categorica',
            data= df, 
            kind='count',
            order= lista_de_orden)
plt.show()

# %% [markdown]
# **Bar Plots**
#
# Son similares a count plots, pero en lugar de contar las observaciones de cada categoría, muestra la media de la variable cuantitativa en relación a todas las observaciones de cada categoría. También puede mostrar el intervalo de confianza al 95% de forma automática

# %%
sns.catplot(x= 'variable categorica',
            y= 'var y',
            data= df, 
            kind='bar')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)
#
#    **Al igual que con los line plots, si queremos sacar el intervalo de confianza, le ponemos ci=None**
#
#    **Cambiando el orden de los parametros x e y podemos dar vuelta las barras**

# %% [markdown]
# ### **Box plots**
#
# Para crear un box plot, tenemos que cambiarle el kind al catplot, y ponerle 'box'

# %%
sns.catplot(x= 'variable categorica',
            y= 'var y',
            data= df, 
            kind='box')
plt.show()

# %% [markdown]
# Si quiero omitir los outliers del boxplot, puedo hacerlo con el parámetro **"sym"**. Si le pasas una string vacia a este, se van a omitir todos los outliers del plot.
# *sym también puede servir para cambiarle la apariencia a los outliers*.

# %%
sns.catplot(x= 'variable categorica',
            y= 'var y',
            data= df, 
            kind='box', 
            sym= '')
plt.show()

# %% [markdown]
# Por defecto, los bigotes valen 1.5 el rango entre caurtiles (IQR). Puedo cambiar esto con el parámetro **'whis'**. Por ejemplo, puedo poner que valgan 2 en lugar de 1.5 poniendo
#
# whis=2.0
#
# O pasandole una lista con los valores mínimos y máximos. Por ejemplo
#
# whis=[5, 95]

# %% [markdown]
# ### **Point plots**

# %% [markdown]
# Los point plots muestran la media de una variable cuantitativa para las observaciones en cada categoría, expresados en un solo punto, junto con el intervalo de confianza del 95%

# %%
sns.catplot(x= 'variable categorica',
            y= 'var y',
            data= df,
            hue='tercer variable',
            kind='point')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Si queremos evitar que este gráfico tenga las lineas que unen cada punto, puedo quitarlas seteando el parametro **'join'** como False

# %%
sns.catplot(x= 'variable categorica',
            y= 'var y',
            data= df,
            hue='tercer variable',
            kind='poin', 
            join= False)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Plots categóricos, parte 2

# %% [markdown]
# Seaborn comprende gráficos categóricos en tres grupos:
# - El primer grupo comprende el ```stirplot()``` y el ```swarmplot()```, que muestran todas las observaciones individuales en un plot.
# - La segunda categoría contiene al ```boxplot()```, ```violinplot()``` y a ```lvplot()```. Estos plots muestran una representación abstracta de la data categórica.
# - El grupo final muestra estimaciones estadísticas de las variables categóricas. Acá incluye el ```barplot()```, ```pointplot()``` y ```countplot()```. Los dos primeros contienen resumenes de data importante; el tercero muestra el número de instancias de cada observación.

# %%
sns.stripplot(data=df, y='yvar',              
              x='xvar',              
              jitter=True)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.swarmplot(data=df, y='yvar',              
              x='xvar')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.violinplot(data=df, y='yvar',              
              x='xvar')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#lvplot= letter value plot
sns.lvplot(data=df, y='yvar',              
              x='xvar')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.barplot(data=df, y='yvar',              
            x='xvar', 
           hue='tercer variable')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Otras customizaciones**
#
# __Cambiar la referencia de la media a la mediana__:
#     Para esto hay que importar la función 'median' de numpy y pasarsela al parámetro **estimator**

# %%
from numpy import median
sns.catplot(x= 'variable categorica',
            y= 'var y',
            data= df,
            hue='tercer variable',
            kind='point', 
            estimator= median)
plt.show()

# %% [markdown]
# __Añadir caps al gráfico:__
# Esto se hace con el parámetro **'capsize'**

# %%
sns.catplot(x= 'variable categorica',
            y= 'var y',
            data= df,
            kind='point', 
            capsize=0.2)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Histograma

# %%
sns.distplot('xvar')

# %% [markdown]
# Esto me va a dar como resultado un histograma que adicionalmente marque la distribución de la muestra
# ![image.png](attachment:image.png)
#
# Para sacarle el line plot y personalizar el numero de filas:

# %%
sns.distplot('xvar', kde=False, bins=*n bins*)

# %% [markdown]
# Otro tipo de distplot

# %%
sns.distplot('xvar', hist=False, rug=True)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# distplot también combina kdeplot y rugplot, por eso permite ponerle los argumentos de estos

# %%
sns.distplot('xvar', hist=False, rug=True, kde_kws={'shade': True})

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Plotear Regresión Lineal
#
# Para esto se utiliza el tipo ```regplot```

# %%
sns.regplot(x='xvar', y="yvar", data=df)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Otro tipo de gráfico para realizar es el ```lmplot```, que es mucho mas potente que el anterior debido a su flexibilidad

# %%
sns.lmplot(x='xvar', y="yvar", data=df, hue='tercer var')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Para hacer lo mismo que arriba, pero disponerlo en dos columnas distintas uso el argumento ```col```

# %%
sns.lmplot(x='xvar', y="yvar", data=df, col='tercer var')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Con el argumento ```marker```, lo que hago es cambiarle la forma a los puntos del gráfico

# %% [markdown]
# **Si quiero ver cómo funcionan los errores en la base de datos, puedo usar el ploteo de ```residplot()```**

# %%
sns.residplot(data=df, x='xvar', y='yvar')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Si añado el parametro ```order``` a regplot, y le asigno un valor mayor a 1, seaborn realizará un fit polinómico utilizando funciones de Numpy por debajo**

# %%
sns.regplot(data=df, x='xvar', y='yvar', order=2)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# De similar manera, puedo calcular el ```residplot()``` a esto

# %%
sns.residplot(data=df, x='xvar', y='yvar', order=2)

# %% [markdown]
# **Seaborn tambien puede graficar regplots con variables categóricas**

# %%
sns.regplot(data=df, x='var categórica', y='var y', x_jitter=.1, order=2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Tambien puedo agregarle un estimador a la función para tener una referencia

# %%
sns.regplot(data=df, x='categorica', y='var y',            
            x_estimator=np.mean, order=2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Cuando la variable es continua, puedo descomprimirla en diferentes *bins*, esto puede solucionarse con el parametro ```x_bins```

# %%
sns.regplot(data=df, x='var x', y='var y',            
            x_bins=4)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Matrix Plots

# %% [markdown]
# El plot de matrices mas comun es el mapa de calor, y puede ser creado facilmente por seaborn. La función ```heatmap()``` es la encargada de hacer esto, pero para eso necesita que la información esté dispuesta en forma de matriz. Para manejar esto, se usa frecuentemente ```crosstab()``` de Pandas.

# %%
#Crosstab
pd.crosstab('var filas', 'var columnas',values='valores con los que quiero rellenar',aggfunc='mean').round(0)
#Heatmap
sns.heatmap(pd.crosstab('var filas', 'var columnas',values='valores con los que quiero rellenar',aggfunc='mean'))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.heatmap(df_crosstab, annot=True, fmt="d", cmap="YlGnBu", cbar=False, linewidths=.5)

# %% [markdown]
# Lo primero que hacemos acá es poner ```annot=True``` para activar las anotaciones sobre las celdas individuales. ```fmt='d'``` se asegura que los numeros estén dispuestos como enteros. Despues, con ```cmap='YlGnBu'``` establecemos un degradé de azul, verde y azul. con ```cbar=False``` no se muestra la barra de colores del costado, y con ```linewidths=.5``` le pone una pequeña separación entre grillas. El resultado final se ve así:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Finalmente, lo que vamos a customizar es el centro de colores del heatmap:

# %%
sns.heatmap(df_crosstab, annot=True, fmt="d", cmap="YlGnBu", cbar=True, center=df_crosstab[*n fila*, *n columna*])

# %% [markdown]
# Una funcionalidad común para el heatmap es para calcular la correlación entre variables:

# %%
sns.heatmap(df.corr())

# %% [markdown]
# ## Facetgrid, factorplot y lmplot

# %% [markdown]
# El concepto de los gráficos múltiples es ideal para datasets con muchas variables. Esto permite identificar tendencias rápidamente comparando múltiples gráficos, uno al lado del otro, usando la misma escala y ejes. Estos plots son referidos como **trellis o lattice plot**. En Data Science, este concepto es normalmente llamado *__Faceting__*.
# **FacetGrid** se encarga de organizar la data en forma que se disponga según filas, columnas y hue, y luego sea utilizada con el tipo apropiado de plot. ```FacetGrid()``` es muy flexible, pero es necesario usar un proceso de dos partes donde primero se definan las Facets y luego se mapee el tipo de plot. Por ejemplo, esta es una forma de usar ```FacetGrid()``` con boxplot:

# %%
g = sns.FacetGrid(df, col="var categorica a plotear") #PRIMERO, definimos los facets
g.map(sns.boxplot, 'var continua a usar',       
      order=[*orden de los valores de la columna que utilizo*]) #SEGUNDO, mapeamos los facets

# %% [markdown]
# ```factorplot()``` **es una manera sencilla de utilizar ```FacetGrid()``` sobre variables categóricas**. Combina los procesos de faceting y mapping en una sola linea.

# %%
sns.factorplot(x='var x continua', data=df,               
               col="var col categorica", kind='box') #boxplot para este caso

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ```FacetGrid()``` también soporta plots de matplotlib. Por ejemplo:

# %% [markdown]
# ```FacetGrid()``` también soporta ploteos de matplotlib

# %%
g = sns.FacetGrid(df, col="var col")
g.map(plt.scatter, 'var x', 'SAT_AVG_ALL')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# La función ```lmplot()``` es similar a ```factorplot()```: proporciona un atajo para crear plots de regresiones y puntos en ```FacetGrid()```

# %%
sns.lmplot(data=df, x="Tuition", y="SAT_AVG_ALL",           
           col="HIGHDEG", fit_reg=False)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.lmplot(data=df, x="Tuition", y="SAT_AVG_ALL",           
           col="HIGHDEG", row='REGION')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## PairGrid y pairplot

# %% [markdown]
# Son similares a FacetGrid, factorplot y lmplot porque nos permiten ver tendencias a través de diferentes columnas de data. La diferencia es que **solo definimos las columnas de data que queremos comparar**.
# El procedimiento para hacer el ```PairGrid()``` es similar al que se usa en ```FacetGrid()```, primero definis las Facets y luego mapeas el tipo de plot de la grilla.
# __Lo interesante de este codigo es que no tenemos que definir los parametros de fila y columna.__

# %%
g = sns.PairGrid(df, vars=["var 1","var 2"])
g = g.map(plt.scatter)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# El gráfico en linea recta, sin embargo, no nos dice mucho al respecto. Podemos cambiar el tipo de gráfico de la siguiente manera:

# %%
g = sns.PairGrid(df, vars=["var 1","var 2"])
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter)
#map_diag y map_offdiag definen los gráficos de las diagonales.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ```pairplot()``` es una función de atajo que simplifica a ```PairGrid()```.

# %%
sns.pairplot(df, vars=["var 1","var 2"], kind='reg',             
             diag_kind='hist')

# %% [markdown]
# ![image.png](attachment:image.png)
#
# También, podemos añadir customizaciones extras a los plots

# %%
sns.pairplot(df.query('BEDRMS < 3'),              
             vars=['var 1', 'var 2', 'var 3'],             
             hue='BEDRMS', palette='husl',             
             plot_kws={'alpha': 0.5})

# %% [markdown]
# ![image.png](attachment:image.png)
#
# **También es posible específicar qué variables quiero que vayan en el eje y y cuales en el eje x:**

# %%
# Build a pairplot with different x and y variables
sns.pairplot(data=df,
        x_vars=["var 1x", "var 2x"],
        y_vars=["var 1y", "var 2h"],
        kind='scatter',
        hue='Region',
        palette='husl')

plt.show()
plt.clf()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## JointGrid y jointplot

# %% [markdown]
# El ```JointGrid()``` nos permite comparar distribución de data entre dos variables.

# %%
g = sns.JointGrid(data=df, x="var x",                  
                  y="var y") 
g.plot(sns.regplot, sns.distplot)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Tambien podemos customizar el JointGrid() y ponerle, por ejemplo, kde en el centro

# %%
g = sns.JointGrid(data=df, x="Tuition",                  
                  y="ADM_RATE_ALL") 
g = g.plot_joint(sns.kdeplot)
g = g.plot_marginals(sns.kdeplot, shade=True)
g = g.annotate(stats.pearsonr)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# El ```jointplot()``` es mas facil de usar, pero provee de menor flexibilidad para customizar

# %%
sns.jointplot(data=df, x="Tuition",              
              y="ADM_RATE_ALL", kind='hex')

# %% [markdown]
# ![image.png](attachment:image.png)
#
# También, podemos customizar distintas características como por ejemplo la data que ponemos dentro y los ejes que utilizamos. Veamos un ejemplo puntual:

# %%
g = (sns.jointplot(x="Tuition",                   
                   y="ADM_RATE_ALL", kind='scatter',                   
                   xlim=(0, 25000),                   
                   marginal_kws=dict(bins=15,rug=True),                   
                   data=df.query('UG < 2500 & Ownership == "Public"')) 
     .plot_joint(sns.kdeplot))

# %% [markdown]
# Al incluir la funcion ```plot_joint(sns.kdeplot)```, se superpone un kdeplot al scatterplot
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Customize plots

# %% [markdown]
# 'style' incluye cambios en el fondo y en los ejes. Hay opciones de preset:
# - white
# - dark
# - whitegrid
# - blackgrid
# - ticks
#
# para setear estos estilos de forma global hay que utilizar la función ```sns.set_style()```
#
# También pueden cambiarse los colores de los elementos principales de un plot con la función ```sns.set_palette()``` . Con esta podes usar paleta ya precargadas por seaborn, o presonalizar la tuya. Para agregar paletas preexistentes, solo hay que pasarle el nombre de la paleta que ya existe. Para personalizar la propia, hay que pasarle una lista con los colores que queremos utilizar (por nombre o por codigo hexadecimal).

# %% [markdown]
# Con el codigo ```sns.set(color_codes=True)```, cualquier paleta de colores de matplotlib puede ser mapeada en una paleta de seaborn, entoncesd despues de eso puedo usar el argumento 'color' en el plot

# %%
sns.set(color_codes=True)
sns.distplot(df['Tuition'], color='g')

# %% [markdown]
# **Para visualizar todos los tipos de paletas**

# %%
for p in sns.palettes.SEABORN_PALETTES:    
    sns.set_palette(p)    
    sns.palplot(sns.color_palette())    
    plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# La función ```sns.palplot()``` permite graficar la paleta de colores que cité dentro, para verla de una manera mas ordenada. A modo de ejemplo:

# %%
sns.palplot(sns.color_palette('Purples',8))
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Cambio de escala
#
# ```sns.set_context()```  es la función para esto. Las escalas, de mas pequeñas a mas grandes son:
# - paper
# - notebook
# - talk
# - poster

# %% [markdown]
# ### Personalizar ejes
#
# Personalizar título de un FacetGrid:

# %%
g= sns.catplot(x='var x', y='var y', 
              data= data, kind= 'box')
g.fig.suptitle('Titulo', y= 1.03)

# %% [markdown]
# Con el argumento 'y' de suptitle lo que hacemos es regular la separación que tiene el título con respecto al gráfico (el valor por default es 1)

# %% [markdown]
# Personalizar título de un AxesSubplot:

# %%
g.set_title('Titulo', y= 1.03)

# %% [markdown]
# Entre estos dos tipos de títulos hay una diferencia. Si yo tengo una serie de subplots y utilizo ```g.fig.suptitle()```, le vamos a dar título a toda la figura, es decir, a todos los gráficos.
# Para cambiarle el titulo a cada uno de los gráficos hay que usar ```g.set_title()```

# %% [markdown]
# **Para girar los valores en el eje X** uso la función de matplotlib ```plt.xticks(rotation=)```

# %% [markdown]
# **Para cambiar el valor de los ejes** tengo que usar la variable:
#
# ```g.set(xlabel="New X Label",
#     ylabel="New Y Label")```

# %% [markdown]
# **Para el caso de variables continuas, si quiero limitar la escala utilizada en el eje X** voy autilizar el argumento ```xlim=(rango de limite)```. Como forma de ejemplo

# %%
fig, ax = plt.subplots()
sns.distplot(df['Tuition'], ax=ax)
ax.set(xlabel="Tuition 2013-14",       
       ylabel="Distribution", xlim=(0, 50000), 
       title="2013-14 Tuition and Fees Distribution")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Para crear dos plots que compartan los mismos valores de un eje, puedo usar el argumento** ```sharey``` o ```sharex```

# %%
fig, (ax0, ax1) = plt.subplots(nrows=1,ncols=2, 
                               sharey=True, figsize=(7,4))
sns.distplot(df['Tuition'], ax=ax0)
sns.distplot(df.query('State == "MN"')['Tuition'], ax=ax1)
ax1.set(xlabel="Tuition (MN)", xlim=(0, 70000))
ax1.axvline(x=20000, label='My Budget', linestyle='--')
ax1.legend()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Añadir lineas de referencia con ```axvline()```
#
# Este método permite añadir lineas de referencia en el eje x. Veamos un ejemplo donde se insertan dos referencias: una con la mediana y otra con la media

# %%
# Create a figure and axes. Then plot the data
fig, ax = plt.subplots()
sns.distplot(df['fmr_1'], ax=ax)

# Customize the labels and limits
ax.set(xlabel="1 Bedroom Fair Market Rent", xlim=(100,1500), title="US Rent")

# Add vertical lines for the median and mean
ax.axvline(x=df['fmr_1'].median(), color='m', label='Median', linestyle='--', linewidth=2)
ax.axvline(x=df['fmr_1'].mean(), color='b', label='Mean', linestyle='-', linewidth=2)

# Show the legend and plot the data
ax.legend()
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)
